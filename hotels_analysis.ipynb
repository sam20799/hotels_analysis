# %% [markdown]
# <h2 align='center'>Data Explore</h2>

# %%
import pandas as pd

# %%
df_dates = pd.read_csv("datasets/dim_date.csv")
df_hotels = pd.read_csv("datasets/dim_hotels.csv")
df_rooms = pd.read_csv("datasets/dim_rooms.csv")
df_agg_bookings = pd.read_csv("datasets/fact_aggregated_bookings.csv")
df_bookings = pd.read_csv("datasets/fact_bookings.csv")

# %%
df_dates.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.city.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_rooms.head().shape
# Out:
# (4, 2)

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_agg_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560])

# %%
df_agg_bookings.property_id.value_counts()
# Out:
# property_id
# 16559    368
# 17559    368
# 17564    368
# 19561    368
# 19559    368
# 18563    368
# 18562    368
# 18561    368
# 18559    368
# 18558    368
# 17563    368
# 17562    368
# 16563    368
# 19562    368
# 16562    368
# 16561    368
# 16560    368
# 17561    368
# 19560    368
# 19558    368
# 17560    368
# 16558    368
# 17558    368
# 19563    368
# 18560    368
# Name: count, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
highest_capacity = df_agg_bookings.capacity.max().item()
df_agg_bookings[df_agg_bookings.capacity==highest_capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# <h2 align='center'>Data Cleaning</h2>

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings = df_bookings[df_bookings.no_guests>0]

# %%
df_bookings.revenue_generated.max(),df_bookings.revenue_generated.min()
# Out:
# (np.int64(28560000), np.int64(6500))

# %%
# handel outlier in revenue generated columns
mean_rg,std_rg = df_bookings.revenue_generated.mean(),df_bookings.revenue_generated.std()
lower_limit = mean_rg - 3*std_rg
higher_limit = mean_rg + 3*std_rg
lower_limit,higher_limit
# Out:
# (np.float64(-263742.4278567056), np.float64(294498.50173207896))

# %%
df_bookings = df_bookings[df_bookings.revenue_generated<=higher_limit]

# %%
df_bookings[df_bookings.revenue_generated<lower_limit]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
# checking revenue realized column

mean_rr,std_rr = df_bookings.revenue_realized.mean(),df_bookings.revenue_realized.std()
lower_limit = mean_rr - 3*std_rr
higher_limit = mean_rr + 3*std_rr
lower_limit,higher_limit
# Out:
# (np.float64(-8087.391491611072), np.float64(33479.358661845814))

# %%
df_bookings[df_bookings.revenue_realized>higher_limit]['room_category'].unique()
# Out:
# array(['RT4'], dtype=object)

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df_bookings[df_bookings.room_category == 'RT4']['revenue_realized'].max()
# Out:
# np.int64(45220)

# %%
# It seem outlier in revenue realized but there is no outlier: prices are high bcz its presedential rooms

# %%
df_bookings.isna().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
# Ignore this also cuz na in rating which is very much possible

# %%
df_agg_bookings.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
df_agg_bookings.isna().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
df_agg_bookings.shape
# Out:
# (9200, 5)

# %%
df_agg_bookings.capacity.median()
# Out:
# np.float64(25.0)

# %%
df_agg_bookings.capacity.fillna(df_agg_bookings.capacity.median(),inplace=True)

# %%
df_agg_bookings[df_agg_bookings.capacity.isna()]
# Out:
# Empty DataFrame
# Columns: [property_id, check_in_date, room_category, successful_bookings, capacity]
# Index: []

# %%
df_agg_bookings.loc[[8,14]]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22      25.0
# 14        17562      1-May-22           RT1                   12      25.0

# %% [markdown]
# <h2 align='center'>Data Transformation</h2>

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings.apply(lambda row: row['successful_bookings']*100/row['capacity'],axis=1)

# %%
df_agg_bookings['occ_pct'] = df_agg_bookings.apply(lambda row: row['successful_bookings']*100/row['capacity'],axis=1)

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67

# %%
df_agg_bookings.occ_pct = df_agg_bookings.occ_pct.round(2)

# %%
df_agg_bookings.groupby('room_category')['occ_pct'].mean()
# Out:
# room_category
# RT1    58.232748
# RT2    58.040278
# RT3    58.028213
# RT4    59.300461
# Name: occ_pct, dtype: float64

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df = pd.merge(df_agg_bookings,df_hotels,on='property_id')

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
#
#    occ_pct  property_name  category       city
# 0    83.33  Atliq Exotica    Luxury     Mumbai
# 1    93.33      Atliq Bay    Luxury  Bangalore
# 2    76.67   Atliq Palace  Business  Bangalore

# %%
df.groupby('city')['occ_pct'].mean()
# Out:
# city
# Bangalore    56.594207
# Delhi        61.606467
# Hyderabad    58.144651
# Mumbai       57.943142
# Name: occ_pct, dtype: float64

# %%
df_dates.head(3)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df,df_dates,left_on='check_in_date',right_on='date')

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct property_name  category       city       date  mmm yy week no  \
# 0    51.72  Atliq Palace  Business  Bangalore  10-May-22  May 22    W 20
# 1    63.33    Atliq City  Business  Hyderabad  10-May-22  May 22    W 20
# 2    60.00     Atliq Bay    Luxury  Bangalore  10-May-22  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday

# %%
df.groupby('day_type')['occ_pct'].mean()
# Out:
# day_type
# weekeday    50.903780
# weekend     72.393432
# Name: occ_pct, dtype: float64

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
df.columns
# Out:
# Index(['property_id', 'check_in_date', 'room_category', 'successful_bookings',
#        'capacity', 'occ_pct', 'property_name', 'category', 'city', 'date',
#        'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_june = df[df['mmm yy']=="Jun 22"]

# %%
df_june.groupby('city')['occ_pct'].mean()
# Out:
# city
# Bangalore    56.578552
# Delhi        62.474286
# Hyderabad    58.458075
# Mumbai       58.382560
# Name: occ_pct, dtype: float64

# %%
df_august = pd.read_csv("datasets/new_data_august.csv")
df_august.head(3)
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67

# %%
df_august.shape,df.shape
# Out:
# ((7, 13), (6500, 13))

# %%
df_august.rename({
    "occ%":"occ_pct"
},axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
#
#    occ_pct property_name  category       city       date  mmm yy week no  \
# 0    51.72  Atliq Palace  Business  Bangalore  10-May-22  May 22    W 20
# 1    63.33    Atliq City  Business  Hyderabad  10-May-22  May 22    W 20
# 2    60.00     Atliq Bay    Luxury  Bangalore  10-May-22  May 22    W 20
#
#    day_type
# 0  weekeday
# 1  weekeday
# 2  weekeday

# %%
df_august.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#    occ_pct
# 0   100.00
# 1    70.00
# 2    76.67
# 3    75.00
# ...

# %%
df_latest = pd.concat([df,df_august],ignore_index=True,axis=0)
df_latest.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        19563     10-May-22           RT3                   15      29.0
# 1        18560     10-May-22           RT1                   19      30.0
# 2        19562     10-May-22           RT1                   18      30.0
# 3        19563     10-May-22           RT1                   16      30.0
# 4        17558     10-May-22           RT1                   11      19.0
#
#    occ_pct property_name  category       city       date  mmm yy week no  \
# 0    51.72  Atliq Palace  Business  Bangalore  10-May-22  May 22    W 20
# 1    63.33    Atliq City  Business  Hyderabad  10-May-22  May 22    W 20
# 2    60.00     Atliq Bay    Luxury  Bangalore  10-May-22  May 22    W 20
# 3    53.33  Atliq Palace  Business  Bangalore  10-May-22  May 22    W 20
# 4    57.89  Atliq Grands    Luxury     Mumbai  10-May-22  May 22    W 20
#
#    day_type room_class
# 0  weekeday        NaN
# 1  weekeday        NaN
# ...

# %%
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_updated = pd.merge(df_bookings,df_hotels,on='property_id')
df_updated.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
rr_per_city = df_updated.groupby('city')['revenue_realized'].sum()
rr_per_city
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(rr_per_city.values,labels=rr_per_city.index,autopct='%1.1f%%',shadow=True)
plt.title("Revenue Realized per City")
plt.show()

# %%
df_dates.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_updated.check_in_date = pd.to_datetime(df_updated.check_in_date,dayfirst=True,format='mixed')

# %%
df_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  datetime64[ns]
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
df_dates.date = pd.to_datetime(df_dates.date)
# Out:
# /var/folders/kg/11tps70n3wb66s6pg8w0z5bc0000gn/T/ipykernel_76783/785890006.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_dates.date = pd.to_datetime(df_dates.date)

# %%
df_dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     datetime64[ns]
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ KB

# %%
df_updated = pd.merge(df_updated,df_dates,left_on='check_in_date',right_on='date',how='left')
df_updated.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    ...  week no_x  day_type_x     date_y mmm yy_y week no_y day_type_y  \
# 0  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
# 1  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
# 2  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
df_updated.columns
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized', 'property_name', 'category', 'city', 'date_x',
#        'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y',
#        'week no_y', 'day_type_y'],
#       dtype='object')

# %%
df_updated.drop(['date_x', 'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y','week no_y', 'day_type_y'],axis=1)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22    2022-05-01
# 1        May012216558RT15        16558     27-04-22    2022-05-01
# 2        May012216558RT16        16558     1/5/2022    2022-05-01
# 3        May012216558RT17        16558     28-04-22    2022-05-01
# 4        May012216558RT18        16558     26-04-22    2022-05-01
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22    2022-07-31
# 134569   Jul312217564RT46        17564     29-07-22    2022-07-31
# 134570   Jul312217564RT48        17564     30-07-22    2022-07-31
# 134571   Jul312217564RT49        17564     29-07-22    2022-07-31
# 134572  Jul312217564RT410        17564     31-07-22    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_updated.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    ...  week no_x  day_type_x     date_y mmm yy_y week no_y day_type_y  \
# 0  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
# 1  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
# 2  ...       W 19     weekend 2022-05-01   May 22      W 19    weekend
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
df_updated.columns
# Out:
# Index(['booking_id', 'property_id', 'booking_date', 'check_in_date',
#        'checkout_date', 'no_guests', 'room_category', 'booking_platform',
#        'ratings_given', 'booking_status', 'revenue_generated',
#        'revenue_realized', 'property_name', 'category', 'city', 'date_x',
#        'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y',
#        'week no_y', 'day_type_y', 'date', 'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df_updated.drop(['date_x',
       'mmm yy_x', 'week no_x', 'day_type_x', 'date_y', 'mmm yy_y',
       'week no_y', 'day_type_y', 'date', 'mmm yy', 'week no', 'day_type'],axis=1,inplace=True)

# %%
df_updated.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_updated = pd.merge(df_updated,df_dates,left_on='check_in_date',right_on='date',how='left')
df_updated.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# ...

# %%
mom_revenue_realized = df_updated.groupby('mmm yy')['revenue_realized'].sum()
mom_revenue_realized
# Out:
# mmm yy
# Jul 22    572843348
# Jun 22    553925855
# May 22    581767396
# Name: revenue_realized, dtype: int64

# %%
plt.bar(mom_revenue_realized.index,mom_revenue_realized.values)
plt.ylabel("In Cr")
plt.title("Month on Month Revenue Realized")
plt.show()

# %%
df_updated.groupby("property_name")['revenue_realized'].sum()
# Out:
# property_name
# Atliq Bay        259996918
# Atliq Blu        260851922
# Atliq City       285798439
# Atliq Exotica    320258588
# Atliq Grands     211462134
# Atliq Palace     304081863
# Atliq Seasons     66086735
# Name: revenue_realized, dtype: int64

# %%
df_updated.groupby('city')['ratings_given'].mean().round(1)
# Out:
# city
# Bangalore    3.4
# Delhi        3.8
# Hyderabad    3.7
# Mumbai       3.7
# Name: ratings_given, dtype: float64

# %%
rr_per_bookings_platform = df_updated.groupby('booking_platform')['revenue_realized'].sum()
rr_per_bookings_platform
# Out:
# booking_platform
# direct offline     86374933
# direct online     168948637
# journey           102531334
# logtrip           187494028
# makeyourtrip      340814104
# others            699306762
# tripster          123066801
# Name: revenue_realized, dtype: int64

# %%
plt.pie(rr_per_bookings_platform.values,labels=rr_per_bookings_platform.index,autopct="%1.0f%%",pctdistance=0.7)
plt.title("Revenue Realized distribution per Booking Platform")
plt.show()
